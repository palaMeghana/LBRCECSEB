# %% [markdown]
# <a href="https://colab.research.google.com/github/palaMeghana/LBRCECSEB/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
from sklearn import svm
import mlxtend
from scipy.stats import zscore
import matplotlib.pyplot as plt
# %matplotlib inline
#Test Train Split
from sklearn import model_selection
from sklearn.model_selection import train_test_split
#Feature Scaling library
from sklearn.preprocessing import StandardScaler
# Check for the VIF values of the feature variables.
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import confusion_matrix
#ROC Curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import classification_report
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from mlxtend.classifier import StackingClassifier
from sklearn.ensemble import RandomForestClassifier
from mlxtend.classifier import StackingCVClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Suppressing Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Data - Parkinsons.csv')

# %%
df.shape # Check number of columns and rows in data frame
# Out:
# (195, 24)

# %%
df.dtypes
# Out:
# name                 object
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %%
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0      0.06545  0.02211  21.033       1  0.414783  0.815285 -4.813031
# 1      0.09403  0.01929  19.085       1  0.458359  0.819521 -4.075192
# 2      0.08270  0.01309  20.651       1  0.429895  0.825288 -4.443179
# 3      0.08771  0.01353  20.644       1  0.434969  0.819235 -4.117501
# 4      0.10470  0.01767  19.649       1  0.417356  0.823484 -3.747787
#
#     spread2        D2       PPE
# 0  0.266482  2.301442  0.284654
# 1  0.335590  2.486855  0.368674
# 2  0.311173  2.342259  0.332634
# 3  0.334147  2.405554  0.368975
# 4  0.234513  2.332180  0.410335
#
# [5 rows x 24 columns]

# %%
df.describe().T
# Out:
#                   count        mean        std         min         25%  \
# MDVP:Fo(Hz)       195.0  154.228641  41.390065   88.333000  117.572000
# MDVP:Fhi(Hz)      195.0  197.104918  91.491548  102.145000  134.862500
# MDVP:Flo(Hz)      195.0  116.324631  43.521413   65.476000   84.291000
# MDVP:Jitter(%)    195.0    0.006220   0.004848    0.001680    0.003460
# MDVP:Jitter(Abs)  195.0    0.000044   0.000035    0.000007    0.000020
# MDVP:RAP          195.0    0.003306   0.002968    0.000680    0.001660
# MDVP:PPQ          195.0    0.003446   0.002759    0.000920    0.001860
# Jitter:DDP        195.0    0.009920   0.008903    0.002040    0.004985
# MDVP:Shimmer      195.0    0.029709   0.018857    0.009540    0.016505
# MDVP:Shimmer(dB)  195.0    0.282251   0.194877    0.085000    0.148500
# Shimmer:APQ3      195.0    0.015664   0.010153    0.004550    0.008245
# Shimmer:APQ5      195.0    0.017878   0.012024    0.005700    0.009580
# MDVP:APQ          195.0    0.024081   0.016947    0.007190    0.013080
# Shimmer:DDA       195.0    0.046993   0.030459    0.013640    0.024735
# NHR               195.0    0.024847   0.040418    0.000650    0.005925
# HNR               195.0   21.885974   4.425764    8.441000   19.198000
# status            195.0    0.753846   0.431878    0.000000    1.000000
# RPDE              195.0    0.498536   0.103942    0.256570    0.421306
# DFA               195.0    0.718099   0.055336    0.574282    0.674758
# spread1           195.0   -5.684397   1.090208   -7.964984   -6.450096
# spread2           195.0    0.226510   0.083406    0.006274    0.174351
# D2                195.0    2.381826   0.382799    1.423287    2.099125
# PPE               195.0    0.206552   0.090119    0.044539    0.137451
#
#                          50%         75%         max
# MDVP:Fo(Hz)       148.790000  182.769000  260.105000
# MDVP:Fhi(Hz)      175.829000  224.205500  592.030000
# MDVP:Flo(Hz)      104.315000  140.018500  239.170000
# MDVP:Jitter(%)      0.004940    0.007365    0.033160
# MDVP:Jitter(Abs)    0.000030    0.000060    0.000260
# MDVP:RAP            0.002500    0.003835    0.021440
# MDVP:PPQ            0.002690    0.003955    0.019580
# Jitter:DDP          0.007490    0.011505    0.064330
# MDVP:Shimmer        0.022970    0.037885    0.119080
# MDVP:Shimmer(dB)    0.221000    0.350000    1.302000
# Shimmer:APQ3        0.012790    0.020265    0.056470
# Shimmer:APQ5        0.013470    0.022380    0.079400
# MDVP:APQ            0.018260    0.029400    0.137780
# Shimmer:DDA         0.038360    0.060795    0.169420
# NHR                 0.011660    0.025640    0.314820
# HNR                22.085000   25.075500   33.047000
# status              1.000000    1.000000    1.000000
# RPDE                0.495954    0.587562    0.685151
# DFA                 0.722254    0.761881    0.825288
# spread1            -5.720868   -5.046192   -2.434031
# spread2             0.218885    0.279234    0.450493
# D2                  2.361532    2.636456    3.671155
# PPE                 0.194052    0.252980    0.527367

# %%
df.isnull().values.any() # If there are any null values in data set
# Out:
# False

# %%
df = df.drop(['name'], axis=1)

# %%
# studying the distribution of continuous attributes mean, median, mode defining the central tendency,
# standard deviation refecting the spread and skewness reflecting the tail
cols = list(df.columns)
cols.remove('status')
for i in np.arange(len(cols)):
    sns.distplot(df[cols[i]], color='blue')
    #plt.xlabel('Experience')
    plt.show()
    print('Distribution of ',cols[i])
    print('Mean is:',df[cols[i]].mean())
    print('Median is:',df[cols[i]].median())
    print('Mode is:',df[cols[i]].mode())
    print('Standard deviation is:',df[cols[i]].std())
    print('Skewness is:',df[cols[i]].skew())
    print('Maximum is:',df[cols[i]].max())
    print('Minimum is:',df[cols[i]].min())
# Out:
# Distribution of  MDVP:Fo(Hz)
# Mean is: 154.22864102564102
# Median is: 148.79
# Mode is: 0       88.333
# 1       91.904
# 2       95.056
# 3       95.385
# 4       95.605
#         ...
# 190    243.439
# 191    244.990
# 192    245.510
# 193    252.455
# 194    260.105
# Name: MDVP:Fo(Hz), Length: 195, dtype: float64
# Standard deviation is: 41.39006474907147
# Skewness is: 0.5917374636540784
# Maximum is: 260.105
# Minimum is: 88.333
# Distribution of  MDVP:Fhi(Hz)
# Mean is: 197.10491794871797
# Median is: 175.829
# Mode is: 0      102.145
# 1      102.305
# 2      107.715
# 3      108.664
# 4      110.019
#         ...
# 190    565.740
# 191    581.289
# 192    586.567
# 193    588.518
# 194    592.030
# Name: MDVP:Fhi(Hz), Length: 195, dtype: float64
# Standard deviation is: 91.49154763503036
# Skewness is: 2.542145997588398
# Maximum is: 592.03
# Minimum is: 102.145
# Distribution of  MDVP:Flo(Hz)
# Mean is: 116.32463076923077
# Median is: 104.315
# Mode is: 0       65.476
# 1       65.750
# 2       65.782
# 3       65.809
# 4       66.004
#         ...
# 190    231.848
# 191    232.435
# 192    232.483
# 193    237.303
# 194    239.170
# Name: MDVP:Flo(Hz), Length: 195, dtype: float64
# Standard deviation is: 43.52141318199365
# Skewness is: 1.217350448627808
# Maximum is: 239.17
# Minimum is: 65.476
# Distribution of  MDVP:Jitter(%)
# Mean is: 0.006220461538461538
# Median is: 0.00494
# Mode is: 0    0.00369
# 1    0.00694
# 2    0.00742
# Name: MDVP:Jitter(%), dtype: float64
# Standard deviation is: 0.00484813369260256
# Skewness is: 3.0849462014441826
# Maximum is: 0.03316
# Minimum is: 0.00168
# Distribution of  MDVP:Jitter(Abs)
# Mean is: 4.395897435897436e-05
# Median is: 3e-05
# Mode is: 0    0.00003
# Name: MDVP:Jitter(Abs), dtype: float64
# Standard deviation is: 3.482190859976326e-05
# Skewness is: 2.6490714165257274
# Maximum is: 0.00026
# Minimum is: 7e-06
# Distribution of  MDVP:RAP
# Mean is: 0.003306410256410257
# Median is: 0.0025
# Mode is: 0    0.00169
# Name: MDVP:RAP, dtype: float64
# Standard deviation is: 0.0029677744162016884
# Skewness is: 3.3607084504805544
# Maximum is: 0.02144
# Minimum is: 0.00068
# Distribution of  MDVP:PPQ
# Mean is: 0.003446358974358974
# Median is: 0.00269
# Mode is: 0    0.00332
# Name: MDVP:PPQ, dtype: float64
# Standard deviation is: 0.0027589766469679313
# Skewness is: 3.0738924578885167
# Maximum is: 0.01958
# Minimum is: 0.00092
# Distribution of  Jitter:DDP
# Mean is: 0.009919948717948717
# Median is: 0.00749
# Mode is: 0    0.00507
# Name: Jitter:DDP, dtype: float64
# Standard deviation is: 0.008903344355858987
# Skewness is: 3.36205844788572
# Maximum is: 0.06433
# Minimum is: 0.00204
# Distribution of  MDVP:Shimmer
# Mean is: 0.0297091282051282
# Median is: 0.02297
# Mode is: 0    0.01450
# 1    0.01503
# 2    0.01608
# 3    0.01725
# 4    0.02293
# 5    0.02448
# 6    0.03273
# Name: MDVP:Shimmer, dtype: float64
# Standard deviation is: 0.01885693185894681
# Skewness is: 1.6664804101559665
# Maximum is: 0.11908
# Minimum is: 0.00954
# Distribution of  MDVP:Shimmer(dB)
# Mean is: 0.2822512820512821
# Median is: 0.221
# Mode is: 0    0.154
# Name: MDVP:Shimmer(dB), dtype: float64
# Standard deviation is: 0.19487729006053414
# Skewness is: 1.999388639086127
# Maximum is: 1.302
# Minimum is: 0.085
# Distribution of  Shimmer:APQ3
# Mean is: 0.015664153846153845
# Median is: 0.01279
# Mode is: 0     0.00469
# 1     0.00522
# 2     0.00633
# 3     0.00728
# 4     0.00769
# 5     0.00829
# 6     0.01277
# 7     0.01284
# 8     0.01441
# 9     0.01484
# 10    0.01579
# Name: Shimmer:APQ3, dtype: float64
# Standard deviation is: 0.010153161595709018
# Skewness is: 1.5805763798815669
# Maximum is: 0.05647
# Minimum is: 0.00455
# Distribution of  Shimmer:APQ5
# Mean is: 0.017878256410256407
# Median is: 0.01347
# Mode is: 0    0.00747
# 1    0.00972
# 2    0.01024
# 3    0.01144
# 4    0.01160
# 5    0.01219
# Name: Shimmer:APQ5, dtype: float64
# Standard deviation is: 0.012023705538741727
# Skewness is: 1.7986970665376225
# Maximum is: 0.0794
# Minimum is: 0.0057
# Distribution of  MDVP:APQ
# Mean is: 0.02408148717948718
# Median is: 0.01826
# Mode is: 0    0.00903
# 1    0.01133
# 2    0.01140
# 3    0.01234
# 4    0.01491
# 5    0.03772
# Name: MDVP:APQ, dtype: float64
# Standard deviation is: 0.016946736247029432
# Skewness is: 2.6180465022154227
# Maximum is: 0.13778
# Minimum is: 0.00719
# Distribution of  Shimmer:DDA
# Mean is: 0.04699261538461539
# Median is: 0.03836
# Mode is: 0    0.01567
# 1    0.01898
# 2    0.02184
# 3    0.03831
# 4    0.04451
# 5    0.04736
# Name: Shimmer:DDA, dtype: float64
# Standard deviation is: 0.030459119431240397
# Skewness is: 1.5806179936782254
# Maximum is: 0.16942
# Minimum is: 0.01364
# Distribution of  NHR
# Mean is: 0.02484707692307692
# Median is: 0.01166
# Mode is: 0    0.00231
# 1    0.00340
# 2    0.00420
# 3    0.00476
# 4    0.00479
# 5    0.00620
# 6    0.00681
# 7    0.00839
# 8    0.01049
# 9    0.07223
# Name: NHR, dtype: float64
# Standard deviation is: 0.04041844855606928
# Skewness is: 4.2207091291390615
# Maximum is: 0.31482
# Minimum is: 0.00065
# Distribution of  HNR
# Mean is: 21.885974358974355
# Median is: 22.085
# Mode is: 0       8.441
# 1       8.867
# 2       9.449
# 3      10.489
# 4      11.744
#         ...
# 190    30.775
# 191    30.940
# 192    31.732
# 193    32.684
# 194    33.047
# Name: HNR, Length: 195, dtype: float64
# Standard deviation is: 4.425764269063427
# Skewness is: -0.5143174975652068
# Maximum is: 33.047
# Minimum is: 8.441
# Distribution of  RPDE
# Mean is: 0.4985355384615385
# Median is: 0.495954
# Mode is: 0      0.256570
# 1      0.263654
# 2      0.276850
# 3      0.296888
# 4      0.305062
#          ...
# 190    0.665318
# 191    0.671299
# 192    0.671378
# 193    0.677131
# 194    0.685151
# Name: RPDE, Length: 195, dtype: float64
# Standard deviation is: 0.10394171413073468
# Skewness is: -0.14340241379821705
# Maximum is: 0.685151
# Minimum is: 0.25657
# Distribution of  DFA
# Mean is: 0.7180990461538461
# Median is: 0.722254
# Mode is: 0      0.574282
# 1      0.582710
# 2      0.605417
# 3      0.623731
# 4      0.626710
#          ...
# 190    0.819521
# 191    0.821364
# 192    0.823484
# 193    0.825069
# 194    0.825288
# Name: DFA, Length: 195, dtype: float64
# Standard deviation is: 0.0553358303465968
# Skewness is: -0.03321366071383457
# Maximum is: 0.825288
# Minimum is: 0.574282
# Distribution of  spread1
# Mean is: -5.684396743589745
# Median is: -5.720868
# Mode is: 0     -7.964984
# 1     -7.777685
# 2     -7.695734
# 3     -7.682587
# 4     -7.517934
#          ...
# 190   -3.269487
# 191   -2.931070
# 192   -2.929379
# 193   -2.839756
# 194   -2.434031
# Name: spread1, Length: 195, dtype: float64
# Standard deviation is: 1.090207763740309
# Skewness is: 0.4321389320131794
# Maximum is: -2.434031
# Minimum is: -7.964984
# Distribution of  spread2
# Mean is: 0.22651034871794873
# Median is: 0.218885
# Mode is: 0    0.210279
# Name: spread2, dtype: float64
# Standard deviation is: 0.08340576262039776
# Skewness is: 0.1444304854927841
# Maximum is: 0.450493
# Minimum is: 0.006274
# Distribution of  D2
# Mean is: 2.3818260871794874
# Median is: 2.361532
# Mode is: 0      1.423287
# 1      1.512275
# 2      1.544609
# 3      1.743867
# 4      1.765957
#          ...
# 190    3.184027
# 191    3.274865
# 192    3.317586
# 193    3.413649
# 194    3.671155
# Name: D2, Length: 195, dtype: float64
# Standard deviation is: 0.3827990465461168
# Skewness is: 0.4303838913329285
# Maximum is: 3.671155
# Minimum is: 1.423287
# Distribution of  PPE
# Mean is: 0.20655164102564103
# Median is: 0.194052
# Mode is: 0      0.044539
# 1      0.056141
# 2      0.057610
# 3      0.068501
# 4      0.073581
#          ...
# 190    0.430788
# 191    0.444774
# 192    0.454721
# 193    0.457533
# 194    0.527367
# Name: PPE, Length: 195, dtype: float64
# Standard deviation is: 0.09011932248227507
# Skewness is: 0.7974910716463577
# Maximum is: 0.527367
# Minimum is: 0.044539

# %%
df["status"].value_counts().plot.bar(title='Freq dist of people with Parkinsons Disease')
# Out:
# <Axes: title={'center': 'Freq dist of people with Parkinsons Disease'}>

# %%
df_corr = df.corr()
plt.subplots(figsize =(12, 7))
sns.heatmap(df_corr,annot=True)
# Out:
# <Axes: >

# %%
# Scatter plot
l = len(df)
#col = ['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)',
#       'MDVP:Shimmer','HNR', 'RPDE', 'DFA',
#       'spread1', 'spread2', 'D2']


col = ['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)','MDVP:Jitter(%)',
       'MDVP:Shimmer','HNR', 'RPDE', 'DFA',
       'PPE', 'spread2', 'D2']
for i in np.arange(len(col)):
#    df.plot(x='MDVP:Fo(Hz)', y='status', kind='scatter')

    sns.scatterplot(x='status',y=col[i], data=df)
    plt.xlabel(col[i])
    plt.ylabel('status')
    plt.show()

# %%
#col = ['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)','MDVP:Shimmer','HNR','RPDE','DFA','spread1','spread2','D2']
sns.pairplot(df[col])
plt.show()

# %%
# Checking the presence of outliers
l = len(df)
#col = ['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)','MDVP:Shimmer','HNR', 'RPDE', 'DFA','spread1', 'spread2', 'D2']
for i in np.arange(len(col)):
    sns.boxplot(x= df[col[i]], color='cyan')
    plt.show()
    print('Boxplot of ',col[i])
    #calculating the outiers in attribute
    Q1 = df[col[i]].quantile(0.25)
    Q2 = df[col[i]].quantile(0.50)
    Q3 = df[col[i]].quantile(0.75)
    IQR = Q3 - Q1
    L_W = (Q1 - 1.5 *IQR)
    U_W = (Q3 + 1.5 *IQR)
    print('Q1 is : ',Q1)
    print('Q2 is : ',Q2)
    print('Q3 is : ',Q3)
    print('IQR is:',IQR)
    print('Lower Whisker, Upper Whisker : ',L_W,',',U_W)
    bools = (df[col[i]] < (Q1 - 1.5 *IQR)) |(df[col[i]] > (Q3 + 1.5 * IQR))
    print('Out of ',l,' rows in data, number of outliers are:',bools.sum())   #calculating the number of outliers
# Out:
# Boxplot of  MDVP:Fo(Hz)
# Q1 is :  117.572
# Q2 is :  148.79
# Q3 is :  182.769
# IQR is: 65.197
# Lower Whisker, Upper Whisker :  19.7765 , 280.5645
# Out of  195  rows in data, number of outliers are: 0
# Boxplot of  MDVP:Fhi(Hz)
# Q1 is :  134.8625
# Q2 is :  175.829
# Q3 is :  224.2055
# IQR is: 89.34299999999999
# Lower Whisker, Upper Whisker :  0.8480000000000132 , 358.22
# Out of  195  rows in data, number of outliers are: 11
# Boxplot of  MDVP:Flo(Hz)
# Q1 is :  84.291
# Q2 is :  104.315
# Q3 is :  140.01850000000002
# IQR is: 55.72750000000002
# Lower Whisker, Upper Whisker :  0.6997499999999661 , 223.60975000000005
# Out of  195  rows in data, number of outliers are: 9
# Boxplot of  MDVP:Jitter(%)
# Q1 is :  0.00346
# Q2 is :  0.00494
# Q3 is :  0.007365
# IQR is: 0.003905
# Lower Whisker, Upper Whisker :  -0.0023975 , 0.0132225
# Out of  195  rows in data, number of outliers are: 14
# Boxplot of  MDVP:Shimmer
# Q1 is :  0.016505
# Q2 is :  0.02297
# Q3 is :  0.037885
# IQR is: 0.021380000000000003
# Lower Whisker, Upper Whisker :  -0.015565000000000002 , 0.069955
# Out of  195  rows in data, number of outliers are: 8
# Boxplot of  HNR
# Q1 is :  19.198
# Q2 is :  22.085
# Q3 is :  25.075499999999998
# IQR is: 5.877499999999998
# Lower Whisker, Upper Whisker :  10.381750000000004 , 33.891749999999995
# Out of  195  rows in data, number of outliers are: 3
# Boxplot of  RPDE
# Q1 is :  0.421306
# Q2 is :  0.495954
# Q3 is :  0.5875625
# IQR is: 0.16625649999999997
# Lower Whisker, Upper Whisker :  0.17192125000000005 , 0.8369472499999999
# Out of  195  rows in data, number of outliers are: 0
# Boxplot of  DFA
# Q1 is :  0.6747575
# Q2 is :  0.722254
# Q3 is :  0.7618815
# IQR is: 0.08712399999999998
# Lower Whisker, Upper Whisker :  0.5440715 , 0.8925675
# Out of  195  rows in data, number of outliers are: 0
# Boxplot of  PPE
# Q1 is :  0.137451
# Q2 is :  0.194052
# Q3 is :  0.25298
# IQR is: 0.11552899999999999
# Lower Whisker, Upper Whisker :  -0.0358425 , 0.42627349999999997
# Out of  195  rows in data, number of outliers are: 5
# Boxplot of  spread2
# Q1 is :  0.17435050000000002
# Q2 is :  0.218885
# Q3 is :  0.279234
# IQR is: 0.10488349999999996
# Lower Whisker, Upper Whisker :  0.017025250000000075 , 0.43655924999999995
# Out of  195  rows in data, number of outliers are: 2
# Boxplot of  D2
# Q1 is :  2.0991255
# Q2 is :  2.361532
# Q3 is :  2.636456
# IQR is: 0.5373304999999999
# Lower Whisker, Upper Whisker :  1.29312975 , 3.44245175
# Out of  195  rows in data, number of outliers are: 1

# %%
#Removing outliers by removing data below lower whisker and above upper whisker
l = len(df)
#col = ['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)','MDVP:Shimmer','HNR', 'RPDE', 'DFA','spread1','spread2', 'D2']
for i in np.arange(len(col)):
    Q1 = df[col[i]].quantile(0.25)
    Q3 = df[col[i]].quantile(0.75)
    IQR = Q3 - Q1
    df = df[(df[col[i]] > (Q1 - 1.5 *IQR)) & (df[col[i]] < (Q3 + 1.5 *IQR))]

# %%
# verifying for  under represented class in 'status' column
df['status'].value_counts()
# Out:
# 1    118
# 0     35
# Name: status, dtype: int64

# %%
# show cleaned-up dataset
df.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
# 2      116.682       131.111       111.555         0.01050           0.00009
# 3      116.676       137.871       111.366         0.00997           0.00009
# 5      120.552       131.162       113.787         0.00968           0.00008
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0   0.00370   0.00554     0.01109       0.04374             0.426  ...
# 1   0.00465   0.00696     0.01394       0.06134             0.626  ...
# 2   0.00544   0.00781     0.01633       0.05233             0.482  ...
# 3   0.00502   0.00698     0.01505       0.05492             0.517  ...
# 5   0.00463   0.00750     0.01388       0.04701             0.456  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0      0.06545  0.02211  21.033       1  0.414783  0.815285 -4.813031
# 1      0.09403  0.01929  19.085       1  0.458359  0.819521 -4.075192
# 2      0.08270  0.01309  20.651       1  0.429895  0.825288 -4.443179
# 3      0.08771  0.01353  20.644       1  0.434969  0.819235 -4.117501
# 5      0.06985  0.01222  21.378       1  0.415564  0.825069 -4.242867
#
#     spread2        D2       PPE
# 0  0.266482  2.301442  0.284654
# 1  0.335590  2.486855  0.368674
# 2  0.311173  2.342259  0.332634
# 3  0.334147  2.405554  0.368975
# 5  0.299111  2.187560  0.357775
#
# [5 rows x 23 columns]

# %%
X_bank = df.drop(['status'], axis=1)
X = df.drop(['status'], axis=1)
y = df['status']

# %%
#Scaling data
SC = StandardScaler()
XSC= SC.fit_transform(X)

# %%
# 4. Split the data into training and test set in the ratio of 70:30 respectively (5 marks)

X_train, X_test, y_train, y_test = train_test_split(XSC, y, train_size=0.7, test_size=0.3, random_state=56)

# %%
# verifying to ensure there are some records with 'status' = 1 for training and testing both.
print('y_train value counts are:\n',y_train.value_counts())
print('y_test value counts are:\n',y_test.value_counts())
# Out:
# y_train value counts are:
#  1    82
# 0    25
# Name: status, dtype: int64
# y_test value counts are:
#  1    36
# 0    10
# Name: status, dtype: int64
